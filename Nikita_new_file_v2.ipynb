# %%
import pandas as pd
import random
import seaborn as sns

# %%
df = pd.read_csv("SalaryData.csv")

# %%
df
# Out:
#       Unnamed: 0   Age  Gender    Education Level              Job Title  \
# 0              0  32.0    Male         Bachelor's      Software Engineer
# 1              1  28.0  Female           Master's           Data Analyst
# 2              2  45.0    Male                PhD         Senior Manager
# 3              3  36.0  Female         Bachelor's        Sales Associate
# 4              4  52.0    Male           Master's               Director
# ...          ...   ...     ...                ...                    ...
# 6699        6699  49.0  Female                PhD  Director of Marketing
# 6700        6700  32.0    Male        High School        Sales Associate
# 6701        6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702        6702  46.0    Male    Master's Degree      Marketing Manager
# 6703        6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary    Country        Race
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6704 entries, 0 to 6703
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           6704 non-null   int64
#  1   Age                  6702 non-null   float64
#  2   Gender               6702 non-null   object
#  3   Education Level      6701 non-null   object
#  4   Job Title            6702 non-null   object
#  5   Years of Experience  6701 non-null   float64
#  6   Salary               6699 non-null   float64
#  7   Country              6704 non-null   object
#  8   Race                 6704 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 471.5+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Age                    2
# Gender                 2
# Education Level        3
# Job Title              2
# Years of Experience    3
# Salary                 5
# Country                0
# Race                   0
# dtype: int64

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's", "Master's", 'PhD', nan, "Bachelor's Degree",
#        "Master's Degree", 'High School', 'phD'], dtype=object)

# %%
df[df['Education Level'].isnull()]
# Out:
#       Unnamed: 0   Age Gender Education Level  Job Title  Years of Experience  \
# 172          172   NaN    NaN             NaN        NaN                  NaN
# 260          260   NaN    NaN             NaN        NaN                  NaN
# 2011        2011  27.0   Male             NaN  Developer                  7.0
#
#         Salary Country   Race
# 172        NaN      UK  White
# 260        NaN  Canada  White
# 2011  100000.0      UK  White

# %%
can_race = df[(df['Country'] == "Canada") & (df['Race'] == "White") ]

# %%
can_race
# Out:
#       Unnamed: 0   Age  Gender    Education Level                  Job Title  \
# 2              2  45.0    Male                PhD             Senior Manager
# 25            25  28.0  Female         Bachelor's    Social Media Specialist
# 33            33  39.0  Female         Bachelor's       Marketing Specialist
# 56            56  27.0  Female           Master's              UX Researcher
# 58            58  30.0  Female         Bachelor's       Social Media Manager
# ...          ...   ...     ...                ...                        ...
# 6581        6581  27.0  Female  Bachelor's Degree       Sales Representative
# 6592        6592  51.0    Male                PhD          Marketing Manager
# 6598        6598  28.0    Male                PhD          Marketing Manager
# 6651        6651  43.0  Female    Master's Degree  Digital Marketing Manager
# 6660        6660  46.0    Male    Master's Degree      Director of Marketing
#
# ...

# %%
can_race.describe()
# Out:
#         Unnamed: 0         Age  Years of Experience         Salary
# count   436.000000  435.000000           435.000000     433.000000
# mean   3228.126147   33.666667             8.126437  115961.212471
# std    1936.271891    7.540775             6.053153   54279.829856
# min       2.000000   23.000000             0.000000   25000.000000
# 25%    1504.250000   28.000000             3.000000   70000.000000
# 50%    3203.500000   32.000000             7.000000  120000.000000
# 75%    4739.000000   38.000000            11.000000  160000.000000
# max    6660.000000   56.000000            31.000000  240000.000000

# %%
can_race['Years of Experience'].mean()
# Out:
# 8.126436781609195

# %%
can_white_mean = can_race['Salary'].mean()

# %%
can_white_mean
# Out:
# 115961.21247113164

# %%
import seaborn as sns

# %%
sns.lineplot(data=df.iloc[:,:], x="Age", y="Salary",)
# Out:
# <Axes: xlabel='Age', ylabel='Salary'>

# %%
mean_values_can_race = round(can_race['Salary'].mean())

# %%
df[df['Salary'].isnull()]
# Out:
#       Unnamed: 0   Age  Gender    Education Level            Job Title  \
# 172          172   NaN     NaN                NaN                  NaN
# 260          260   NaN     NaN                NaN                  NaN
# 3136        3136  31.0    Male    Master's Degree  Full Stack Engineer
# 5247        5247  26.0  Female  Bachelor's Degree             Social M
# 6455        6455  36.0    Male  Bachelor's Degree       Sales Director
#
#       Years of Experience  Salary Country   Race
# 172                   NaN     NaN      UK  White
# 260                   NaN     NaN  Canada  White
# 3136                  8.0     NaN  Canada  White
# 5247                  NaN     NaN     USA  White
# 6455                  6.0     NaN  Canada  White

# %%
df[(df['Country'] == "Canada") & (df['Race'] == "White")]
# Out:
#       Unnamed: 0   Age  Gender    Education Level                  Job Title  \
# 2              2  45.0    Male                PhD             Senior Manager
# 25            25  28.0  Female         Bachelor's    Social Media Specialist
# 33            33  39.0  Female         Bachelor's       Marketing Specialist
# 56            56  27.0  Female           Master's              UX Researcher
# 58            58  30.0  Female         Bachelor's       Social Media Manager
# ...          ...   ...     ...                ...                        ...
# 6581        6581  27.0  Female  Bachelor's Degree       Sales Representative
# 6592        6592  51.0    Male                PhD          Marketing Manager
# 6598        6598  28.0    Male                PhD          Marketing Manager
# 6651        6651  43.0  Female    Master's Degree  Digital Marketing Manager
# 6660        6660  46.0    Male    Master's Degree      Director of Marketing
#
# ...

# %%
can_race['Salary'].max()
# Out:
# 240000.0

# %%
usa_ex_sal = df[(df['Country'] == "USA") & (df['Race'] == "White")]

# %%
usa_ex_sal_mean = round(usa_ex_sal['Salary'].mean())

# %%
usa_yoe_mean = round(usa_ex_sal['Years of Experience'].mean())

# %%
usa_ex_sal.describe()
# Out:
#         Unnamed: 0         Age  Years of Experience         Salary
# count   348.000000  348.000000           347.000000     347.000000
# mean   3391.258621   33.781609             8.370317  115763.792507
# std    1812.607222    7.822122             6.341137   53376.877578
# min      45.000000   21.000000             0.000000   25000.000000
# 25%    1929.500000   28.000000             3.000000   70000.000000
# 50%    3392.000000   32.000000             7.000000  115000.000000
# 75%    4876.500000   38.000000            12.000000  160000.000000
# max    6663.000000   58.000000            32.000000  240000.000000

# %%
for i,r in df.iterrows():
    degree = random.choice(["Bachelor's Degree", "Master's Degree", 'PhD','High School'])
    salary = r['Salary']
    country = r['Country']
    Race = r['Race']
    yoe = r['Years of Experience']
    eud_lev = r['Education Level']
    print(i, salary, eud_lev)
    
    if eud_lev == "Bachelor's":
        df.at[i, 'Education Level'] = "Bachelor's Degree"
    if eud_lev == "Master's":
        df.at[i, 'Education Level'] = "Master's Degree"
    if eud_lev == "phD":
        df.at[i, 'Education Level'] = "PhD"
    
    if (country == 'Canada') & (Race == 'White') & (pd.isnull(salary)) :
        df.at[i, 'Salary'] = can_white_mean
    if (country == 'USA') & (Race == 'White') & (pd.isnull(salary)) :
        df.at[i, 'Salary'] = usa_ex_sal_mean
    if (country == 'USA') & (Race == 'White') & (pd.isnull(yoe)) :
        df.at[i, 'Years of Experience'] = usa_yoe_mean
    
    if (country == 'UK') & (Race == 'White') & (pd.isnull(eud_lev)):
        df.at[i,'Education Level'] = degree
#     if (eud_lev.isnull()):
#         df[i,'Education Level'] = degree
# Out:
# 0 90000.0 Bachelor's Degree
# 1 65000.0 Master's Degree
# 2 150000.0 PhD
# 3 60000.0 Bachelor's Degree
# 4 200000.0 Master's Degree
# 5 55000.0 Bachelor's Degree
# 6 120000.0 Master's Degree
# 7 80000.0 Bachelor's Degree
# 8 45000.0 Bachelor's Degree
# 9 110000.0 PhD
# 10 75000.0 Master's Degree
# 11 140000.0 Bachelor's Degree
# 12 65000.0 Bachelor's Degree
# 13 130000.0 Master's Degree
# 14 40000.0 Bachelor's Degree
# 15 125000.0 Bachelor's Degree
# 16 90000.0 Master's Degree
# 17 115000.0 PhD
# 18 35000.0 Bachelor's Degree
# 19 180000.0 Bachelor's Degree
# 20 80000.0 Master's Degree
# 21 190000.0 Master's Degree
# 22 50000.0 Bachelor's Degree
# 23 60000.0 Bachelor's Degree
# 24 140000.0 Master's Degree
# 25 45000.0 Bachelor's Degree
# 26 110000.0 Master's Degree
# 27 40000.0 Bachelor's Degree
# 28 140000.0 PhD
# 29 90000.0 Master's Degree
# 30 250000.0 Bachelor's Degree
# 31 55000.0 Bachelor's Degree
# 32 75000.0 Master's Degree
# 33 65000.0 Bachelor's Degree
# 34 170000.0 PhD
# ...

# %%
df
# Out:
#       Unnamed: 0   Age  Gender    Education Level              Job Title  \
# 0              0  32.0    Male  Bachelor's Degree      Software Engineer
# 1              1  28.0  Female    Master's Degree           Data Analyst
# 2              2  45.0    Male                PhD         Senior Manager
# 3              3  36.0  Female  Bachelor's Degree        Sales Associate
# 4              4  52.0    Male    Master's Degree               Director
# ...          ...   ...     ...                ...                    ...
# 6699        6699  49.0  Female                PhD  Director of Marketing
# 6700        6700  32.0    Male        High School        Sales Associate
# 6701        6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702        6702  46.0    Male    Master's Degree      Marketing Manager
# 6703        6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary    Country        Race
# ...

# %%
# df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Age                    2
# Gender                 2
# Education Level        1
# Job Title              2
# Years of Experience    3
# Salary                 3
# Country                0
# Race                   0
# dtype: int64

# %%
df[df['Age'].isnull()]
# Out:
#      Unnamed: 0  Age Gender  Education Level Job Title  Years of Experience  \
# 172         172  NaN    NaN  Master's Degree       NaN                  NaN
# 260         260  NaN    NaN              NaN       NaN                  NaN
#
#             Salary Country   Race
# 172            NaN      UK  White
# 260  115961.212471  Canada  White

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# Country                0
# Race                   0
# dtype: int64

# %%
df['Education Level'].unique()
# Out:
# array(["Bachelor's Degree", "Master's Degree", 'PhD', 'High School',
#        'phD'], dtype=object)

# %%
df
# Out:
#       Unnamed: 0   Age  Gender    Education Level              Job Title  \
# 0              0  32.0    Male  Bachelor's Degree      Software Engineer
# 1              1  28.0  Female    Master's Degree           Data Analyst
# 2              2  45.0    Male                PhD         Senior Manager
# 3              3  36.0  Female  Bachelor's Degree        Sales Associate
# 4              4  52.0    Male    Master's Degree               Director
# ...          ...   ...     ...                ...                    ...
# 6699        6699  49.0  Female                PhD  Director of Marketing
# 6700        6700  32.0    Male        High School        Sales Associate
# 6701        6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702        6702  46.0    Male    Master's Degree      Marketing Manager
# 6703        6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary    Country        Race
# ...

# %%
import io

# %%
df.drop(df.filter(regex="Unname"),axis=1, inplace=True)
# Out:
# /var/folders/l1/5ptdcyqx41q753f04b_91cq40000gn/T/ipykernel_36794/864793662.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(df.filter(regex="Unname"),axis=1, inplace=True)

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male  Bachelor's Degree      Software Engineer
# 1     28.0  Female    Master's Degree           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female  Bachelor's Degree        Sales Associate
# 4     52.0    Male    Master's Degree               Director
# ...    ...     ...                ...                    ...
# 6699  49.0  Female                PhD  Director of Marketing
# 6700  32.0    Male        High School        Sales Associate
# 6701  30.0  Female  Bachelor's Degree      Financial Manager
# 6702  46.0    Male    Master's Degree      Marketing Manager
# 6703  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary    Country        Race
# 0                     5.0   90000.0         UK       White
# 1                     3.0   65000.0        USA    Hispanic
# ...

# %%
df.to_csv("clean_salary_data_1.csv")

# %%
df = pd.read_csv("clean_salary_data_1.csv")

# %%
df.drop(df.filter(regex="Unname"),axis=1, inplace=True)

# %%
df
# Out:
#        Age  Gender    Education Level              Job Title  \
# 0     32.0    Male  Bachelor's Degree      Software Engineer
# 1     28.0  Female    Master's Degree           Data Analyst
# 2     45.0    Male                PhD         Senior Manager
# 3     36.0  Female  Bachelor's Degree        Sales Associate
# 4     52.0    Male    Master's Degree               Director
# ...    ...     ...                ...                    ...
# 6695  49.0  Female                PhD  Director of Marketing
# 6696  32.0    Male        High School        Sales Associate
# 6697  30.0  Female  Bachelor's Degree      Financial Manager
# 6698  46.0    Male    Master's Degree      Marketing Manager
# 6699  26.0  Female        High School        Sales Executive
#
#       Years of Experience    Salary    Country        Race
# 0                     5.0   90000.0         UK       White
# 1                     3.0   65000.0        USA    Hispanic
# ...
